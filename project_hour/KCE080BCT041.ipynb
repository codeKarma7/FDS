# %%
#supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#importing required libraries
import pandas as pd #for dataframes
import matplotlib.pyplot as plt #for plotting
import seaborn as sns #for plotting
import numpy as np

df = pd.read_csv("employees.csv")
df
# Out:
#      EmployeeID          Name  Department  Salary JoiningDate   Age Gender   \
# 0           NaN    Employee_1     Finance     NaN  2022-11-03   NaN  Female
# 1         102.0    Employee_2  Operations  4705.0  2016-11-09  29.0    Male
# 2           NaN    Employee_3   Marketing  4026.0  2023-01-26  50.0  Female
# 3         104.0    Employee_4     Finance     NaN  2019-01-23  39.0    Male
# 4         105.0    Employee_5     Finance  6573.0  2018-09-04  25.0    Male
# ..          ...           ...         ...     ...         ...   ...     ...
# 495       596.0  Employee_496   Marketing  5485.0  2016-02-10  40.0    Male
# 496       597.0  Employee_497   Marketing  6273.0  2023-05-28  33.0  Female
# 497       598.0  Employee_498          HR     NaN  2016-05-19  31.0  Female
# 498       599.0  Employee_499     Finance  7539.0  2023-02-10  33.0    Male
# 499       600.0  Employee_500          IT  6669.0  2023-02-17  29.0    Male
#
# ...

# %%
df.shape
# Out:
# (500, 11)

# %%
### 1. Data cleaning and Preprocessing starts from here
df.isnull().sum() #out of 500 data, data ma deko jati chai null xa
# Out:
# EmployeeID             53
# Name                   42
#  Department            12
# Salary                 67
# JoiningDate             0
# Age                    50
# Gender                  0
# Experience (Years)     46
# Performance Rating      0
#  Remote Worker         29
# Last Promotion Date    86
# dtype: int64

# %%
# DropNone values for columns(EmployeeID, Name, JoiningDate )

df.dropna(subset = ['EmployeeID','Name','JoiningDate'],inplace=True)
df.shape #kati ota data baki xa check garna
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406 entries, 1 to 499
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           406 non-null    float64
#  1   Name                 406 non-null    object
#  2    Department          394 non-null    object
#  3   Salary               349 non-null    float64
#  4   JoiningDate          406 non-null    object
#  5   Age                  365 non-null    float64
#  6   Gender               406 non-null    object
#  7   Experience (Years)   368 non-null    float64
#  8   Performance Rating   406 non-null    float64
#  9    Remote Worker       381 non-null    object
#  10  Last Promotion Date  338 non-null    object
# dtypes: float64(5), object(6)
# memory usage: 38.1+ KB
#      EmployeeID          Name  Department  Salary JoiningDate   Age Gender   \
# 1         102.0    Employee_2  Operations  4705.0  2016-11-09  29.0    Male
# ...

# %%
#checking if any column of salary has null value

df['Salary'].isnull().sum()

#calculating mean of the salary
mean_salary = df['Salary'].mean()
print(mean_salary)

#in salary column jaha none xa tyaha mean_salary replace garne
df['Salary']=df['Salary'].fillna(mean_salary)
df
# Out:
# 5938.871060171919
#      EmployeeID          Name  Department      Salary JoiningDate   Age  \
# 1         102.0    Employee_2  Operations  4705.00000  2016-11-09  29.0
# 3         104.0    Employee_4     Finance  5938.87106  2019-01-23  39.0
# 4         105.0    Employee_5     Finance  6573.00000  2018-09-04  25.0
# 5         106.0    Employee_6          IT  5117.00000  2020-01-28  33.0
# 6         107.0    Employee_7          IT  6591.00000  2018-04-10  37.0
# ..          ...           ...         ...         ...         ...   ...
# 495       596.0  Employee_496   Marketing  5485.00000  2016-02-10  40.0
# 496       597.0  Employee_497   Marketing  6273.00000  2023-05-28  33.0
# 497       598.0  Employee_498          HR  5938.87106  2016-05-19  31.0
# 498       599.0  Employee_499     Finance  7539.00000  2023-02-10  33.0
# 499       600.0  Employee_500          IT  6669.00000  2023-02-17  29.0
#
#     Gender   Experience (Years)  Performance Rating  Remote Worker  \
# ...

# %%
#again ensuring that if a salary has missing value or not
df['Salary'].isnull().any()
# Out:
# np.False_

# %%
#checking if any column of age has missing value or not
missing_age = df['Age'].isnull().sum()
print(f"Missing value in 'Age': {missing_age}")
# Out:
# Missing value in 'Age': 41

# %%
#calculating mode of the age
mode_age = df['Age'].mode()[0]
print(f"Mode of 'Age': {mode_age}")

#replacing mode_age in missing values in table
df['Age']=df['Age'].fillna(mode_age)
df
# Out:
# Mode of 'Age': 33.0
#      EmployeeID          Name  Department      Salary JoiningDate   Age  \
# 1         102.0    Employee_2  Operations  4705.00000  2016-11-09  29.0
# 3         104.0    Employee_4     Finance  5938.87106  2019-01-23  39.0
# 4         105.0    Employee_5     Finance  6573.00000  2018-09-04  25.0
# 5         106.0    Employee_6          IT  5117.00000  2020-01-28  33.0
# 6         107.0    Employee_7          IT  6591.00000  2018-04-10  37.0
# ..          ...           ...         ...         ...         ...   ...
# 495       596.0  Employee_496   Marketing  5485.00000  2016-02-10  40.0
# 496       597.0  Employee_497   Marketing  6273.00000  2023-05-28  33.0
# 497       598.0  Employee_498          HR  5938.87106  2016-05-19  31.0
# 498       599.0  Employee_499     Finance  7539.00000  2023-02-10  33.0
# 499       600.0  Employee_500          IT  6669.00000  2023-02-17  29.0
#
#     Gender   Experience (Years)  Performance Rating  Remote Worker  \
# ...

# %%
#checking if any age has missing value

df['Age'].isnull().any()
# Out:
# np.False_

# %%
#checking if department has missing value
df[' Department'].isnull().sum()
# Out:
# np.int64(12)

# %%
#calculating mode for department
mode_depart = df[' Department'].mode()[0]
print(f"Mode of 'Department' : {mode_depart}")

#now replacing missing values with mode result in department section
df[' Department'] = df[' Department'].fillna(mode_depart)
df
# Out:
# Mode of 'Department' : IT
#      EmployeeID          Name  Department      Salary JoiningDate   Age  \
# 1         102.0    Employee_2  Operations  4705.00000  2016-11-09  29.0
# 3         104.0    Employee_4     Finance  5938.87106  2019-01-23  39.0
# 4         105.0    Employee_5     Finance  6573.00000  2018-09-04  25.0
# 5         106.0    Employee_6          IT  5117.00000  2020-01-28  33.0
# 6         107.0    Employee_7          IT  6591.00000  2018-04-10  37.0
# ..          ...           ...         ...         ...         ...   ...
# 495       596.0  Employee_496   Marketing  5485.00000  2016-02-10  40.0
# 496       597.0  Employee_497   Marketing  6273.00000  2023-05-28  33.0
# 497       598.0  Employee_498          HR  5938.87106  2016-05-19  31.0
# 498       599.0  Employee_499     Finance  7539.00000  2023-02-10  33.0
# 499       600.0  Employee_500          IT  6669.00000  2023-02-17  29.0
#
#     Gender   Experience (Years)  Performance Rating  Remote Worker  \
# ...

# %%
#reassuring if the department has missing values
df[' Department'].isnull().any()
# Out:
# np.False_

# %%
#checking number if missing values in Experience(years)
missing_experience = df['Experience (Years)'].isnull().sum()
print(f"Misssing values in 'Experience(years)' : {missing_experience}")
# Out:
# Misssing values in 'Experience(years)' : 38

# %%
#calculating median of the experience(year)
median_experience=df['Experience (Years)'].median()
print(f"Median of 'Experience(year)' : {median_experience}")

#replacing missing value in experience(year) with result of median_experience
df['Experience (Years)'] = df['Experience (Years)'].fillna(median_experience)
df
# Out:
# Median of 'Experience(year)' : 15.0
#      EmployeeID          Name  Department      Salary JoiningDate   Age  \
# 1         102.0    Employee_2  Operations  4705.00000  2016-11-09  29.0
# 3         104.0    Employee_4     Finance  5938.87106  2019-01-23  39.0
# 4         105.0    Employee_5     Finance  6573.00000  2018-09-04  25.0
# 5         106.0    Employee_6          IT  5117.00000  2020-01-28  33.0
# 6         107.0    Employee_7          IT  6591.00000  2018-04-10  37.0
# ..          ...           ...         ...         ...         ...   ...
# 495       596.0  Employee_496   Marketing  5485.00000  2016-02-10  40.0
# 496       597.0  Employee_497   Marketing  6273.00000  2023-05-28  33.0
# 497       598.0  Employee_498          HR  5938.87106  2016-05-19  31.0
# 498       599.0  Employee_499     Finance  7539.00000  2023-02-10  33.0
# 499       600.0  Employee_500          IT  6669.00000  2023-02-17  29.0
#
# ...

# %%
#reassuring if there is a missing value in experience(year)
df['Experience (Years)'].isnull().any()
# Out:
# np.False_

# %%
#converting dataypes into best choice

#checking the datatypes of features
print(df.dtypes)
# Out:
# EmployeeID             float64
# Name                    object
#  Department             object
# Salary                 float64
# JoiningDate             object
# Age                    float64
# Gender                  object
# Experience (Years)     float64
# Performance Rating     float64
#  Remote Worker          object
# Last Promotion Date     object
# dtype: object

# %%
#converting the feature into suitable datatype

df['EmployeeID'] = df['EmployeeID'].astype(int)
df['JoiningDate'] = pd.to_datetime(df['JoiningDate'])
df['Age'] = df['Age'].astype(int)
df['Experience (Years)'] = df['Experience (Years)'].astype(int)
df['Last Promotion Date'] = pd.to_datetime(df['Last Promotion Date'])

#again checking if the conversion of data type takes place 
print(df.dtypes)


#Data cleaning and preprocessing ends here
# Out:
# EmployeeID                      int64
# Name                           object
#  Department                    object
# Salary                        float64
# JoiningDate            datetime64[ns]
# Age                             int64
# Gender                         object
# Experience (Years)              int64
# Performance Rating            float64
#  Remote Worker                 object
# Last Promotion Date    datetime64[ns]
# dtype: object

# %%
#2.Exploratory Data Analysis starts here

#visualizing the distribution of numerical columns using histograms

#histogram of salary

plt.figure(figsize=(20,8))
sns.histplot(data=df['Salary'],bins=30,kde=True)
plt.title('Distribution of Salary')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of age

plt.figure(figsize=(20,8))
sns.histplot(data=df['Age'],bins=30,kde=True)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Histogram of Experience(years)

plt.figure(figsize=(20,8))
sns.histplot(data=df['Experience (Years)'],bins=40,kde=True)
plt.title('Experience Chart of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Histogram of performance rating

plt.figure(figsize=(20,8))
sns.histplot(data=df['Performance Rating'],bins=40,kde=True)
plt.title('Visualization of Performance rating')
plt.xlabel('Performance rating')
plt.ylabel('Frequency')
plt.show()

# %%
###visualizing the distribution of caterogical columns
##this is univariative analysis

#of department

plt.figure(figsize=(10,6))
sns.countplot(x=' Department',data=df)
plt.title('Department Distribution')
plt.xlabel('Department')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
#of Gender

plt.figure(figsize=(10,6))
sns.countplot(x='Gender ',data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
#of remote worker

plt.figure(figsize=(10,6))
sns.countplot(x=' Remote Worker',data=df)
plt.title('Remote Worker Distribution')
plt.xlabel('Remote Workers')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
##starting bivariative analysis

#examining relationships between salary, experience(years) and performance rating using scatter plots

plt.figure(figsize=(20,8))
sns.scatterplot(x='Experience (Years)', y='Salary',data=df)
plt.title('Experience vs Salary')
plt.show()

# %%
#performance rating vs salary
plt.figure(figsize=(20,8))
sns.scatterplot(x='Performance Rating', y='Salary',data=df)
plt.title('Performance Rating vs Salary')
plt.show()

# %%
#experience(years) vs performance rating
plt.figure(figsize=(20,8))
sns.scatterplot(x='Experience (Years)', y='Performance Rating',data=df)
plt.title('Experience vs Performance Rating')
plt.show()

# %%
### 3. Featue Encoding

#one-hot encoding starts here 

categorical_variables = df.dtypes[df.dtypes=="object"].index
categorical_variables

#finding number of unique values for each categorical values

for category in categorical_variables:
    print(f"Number of unique values in {category} = {len(df[category].unique())}")
# Out:
# Number of unique values in Name = 406
# Number of unique values in  Department = 5
# Number of unique values in Gender  = 2
# Number of unique values in  Remote Worker = 3

# %%
#here name have very large number of distinct values so one-hot encoding will not be efficient.
df_clean = df.drop(["Name"],axis=1)
df_clean
# Out:
#      EmployeeID  Department      Salary JoiningDate  Age Gender   \
# 1           102  Operations  4705.00000  2016-11-09   29    Male
# 3           104     Finance  5938.87106  2019-01-23   39    Male
# 4           105     Finance  6573.00000  2018-09-04   25    Male
# 5           106          IT  5117.00000  2020-01-28   33    Male
# 6           107          IT  6591.00000  2018-04-10   37    Male
# ..          ...         ...         ...         ...  ...     ...
# 495         596   Marketing  5485.00000  2016-02-10   40    Male
# 496         597   Marketing  6273.00000  2023-05-28   33  Female
# 497         598          HR  5938.87106  2016-05-19   31  Female
# 498         599     Finance  7539.00000  2023-02-10   33    Male
# 499         600          IT  6669.00000  2023-02-17   29    Male
#
#      Experience (Years)  Performance Rating  Remote Worker Last Promotion Date
# 1                     5                 3.7           True          2024-10-31
# ...

# %%
df_clean.shape
# Out:
# (406, 10)

# %%
categorical_variables = df_clean.dtypes[df_clean.dtypes == "object"].index
categorical_variables
# Out:
# Index([' Department', 'Gender ', ' Remote Worker'], dtype='object')

# %%
df_clean_encoded = pd.get_dummies(df_clean, columns=categorical_variables,drop_first=True)
df_clean_encoded
# Out:
#      EmployeeID      Salary JoiningDate  Age  Experience (Years)  \
# 1           102  4705.00000  2016-11-09   29                   5
# 3           104  5938.87106  2019-01-23   39                  23
# 4           105  6573.00000  2018-09-04   25                  15
# 5           106  5117.00000  2020-01-28   33                  28
# 6           107  6591.00000  2018-04-10   37                  17
# ..          ...         ...         ...  ...                 ...
# 495         596  5485.00000  2016-02-10   40                  28
# 496         597  6273.00000  2023-05-28   33                   6
# 497         598  5938.87106  2016-05-19   31                  22
# 498         599  7539.00000  2023-02-10   33                  27
# 499         600  6669.00000  2023-02-17   29                  29
#
#      Performance Rating Last Promotion Date   Department_HR   Department_IT  \
# 1                   3.7          2024-10-31           False           False
# ...

# %%
encoded_columns = [' Department_HR',' Department_IT',' Department_Marketing',' Department_Operations']
df_clean_encoded[encoded_columns] = df_clean_encoded[encoded_columns].astype(int)
df_clean_encoded


#one hot encoding ends here
# Out:
#      EmployeeID      Salary JoiningDate  Age  Experience (Years)  \
# 1           102  4705.00000  2016-11-09   29                   5
# 3           104  5938.87106  2019-01-23   39                  23
# 4           105  6573.00000  2018-09-04   25                  15
# 5           106  5117.00000  2020-01-28   33                  28
# 6           107  6591.00000  2018-04-10   37                  17
# ..          ...         ...         ...  ...                 ...
# 495         596  5485.00000  2016-02-10   40                  28
# 496         597  6273.00000  2023-05-28   33                   6
# 497         598  5938.87106  2016-05-19   31                  22
# 498         599  7539.00000  2023-02-10   33                  27
# 499         600  6669.00000  2023-02-17   29                  29
#
#      Performance Rating Last Promotion Date   Department_HR   Department_IT  \
# 1                   3.7          2024-10-31               0               0
# ...

# %%
#now binning fpr age starts here 
#first checking maximum and minimum ager for binning
min_age=df['Age'].min()
max_age=df['Age'].max()
print(min_age)
print(max_age)

bins = [0,25,40,50] #defining the bin edges
labels = ['Young','Middle-Aged','Senior'] #cprresponding labels

#adding a new column with binned categories
df['Age_Group'] = pd.cut(df['Age'],bins=bins,labels=labels,right=False)
df

#binnnig ends here
# Out:
# 25
# 50
#      EmployeeID          Name  Department      Salary JoiningDate  Age  \
# 1           102    Employee_2  Operations  4705.00000  2016-11-09   29
# 3           104    Employee_4     Finance  5938.87106  2019-01-23   39
# 4           105    Employee_5     Finance  6573.00000  2018-09-04   25
# 5           106    Employee_6          IT  5117.00000  2020-01-28   33
# 6           107    Employee_7          IT  6591.00000  2018-04-10   37
# ..          ...           ...         ...         ...         ...  ...
# 495         596  Employee_496   Marketing  5485.00000  2016-02-10   40
# 496         597  Employee_497   Marketing  6273.00000  2023-05-28   33
# 497         598  Employee_498          HR  5938.87106  2016-05-19   31
# 498         599  Employee_499     Finance  7539.00000  2023-02-10   33
# 499         600  Employee_500          IT  6669.00000  2023-02-17   29
#
#     Gender   Experience (Years)  Performance Rating  Remote Worker  \
# ...

# %%
### 4.Correlation Analysis

#calculating the correlation matrix for numerical columns

#we will only select numeric columns
numeric_df = df.select_dtypes(include=['number'])

#calculating correlation matrix
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                     EmployeeID    Salary       Age  Experience (Years)  \
# EmployeeID            1.000000  0.066522  0.037397            0.076598
# Salary                0.066522  1.000000 -0.080564            0.015564
# Age                   0.037397 -0.080564  1.000000            0.022630
# Experience (Years)    0.076598  0.015564  0.022630            1.000000
# Performance Rating   -0.093631  0.013145 -0.029574            0.025718
#
#                     Performance Rating
# EmployeeID                   -0.093631
# Salary                        0.013145
# Age                          -0.029574
# Experience (Years)            0.025718
# Performance Rating            1.000000

# %%
#visualizing the correlation matrix using a heatmap to identify relationships between variables

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### 5. Categorical Data Analysis :
#
# 1. What is the distribution of employees across different departments (Department)?
#      Which department has the highest/lowest number of employees?
#
# Ans : The distribution of employees across different departments are given below :

# %%
#we are visualizing the number of employees in different department.

plt.figure(figsize=(10,6))
ax = sns.countplot(x=' Department',data=df)
plt.title('Department Distribution')
plt.xlabel('Department')
plt.ylabel('Count')
plt.grid(True)

#displaying the exact values
counts = df[' Department'].value_counts()
print(counts)

#annotate counts on bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha ='center', va='bottom',fontsize=10, color= 'black')
plt.show()

df.shape
# Out:
#  Department
# IT            97
# Finance       83
# Marketing     82
# Operations    81
# HR            63
# Name: count, dtype: int64
# (406, 12)

# %% [markdown]
# Ans : Number of employees in different Department are calculated above and you can see there.
#
# -The highest employees are in IT Department having 97 employees and the lower employees are in HR having only 63 employees.

# %% [markdown]
# 2. What percentage of employees are remote workers (Remote Worker)? How does this
#  vary across different departments?
#
# Ans :

# %%
#of remote worker

plt.figure(figsize=(10,6))
ax = sns.countplot(x=' Remote Worker',data=df)
plt.title('Remote Worker Distribution')
plt.xlabel('Remote Workers')
plt.ylabel('Count')
plt.grid(True)

total = len(df)
for p in ax.patches:
    percentage = f'{100 * p.get_height() / total:.2f}%'
    ax.annotate(percentage, 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=12, color='black', 
                xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# From the above calculation, we can observe that 47.54 % employees are Remote workers. From this data, we can conclude that people from remote areas are getting large opportunities.

# %% [markdown]
# Ans : The variation of remote workers in different Departments are explained below :

# %%
# Group by department and calculate remote worker counts
department_counts = df.groupby(' Department')[' Remote Worker'].value_counts(normalize=True) * 100

# Convert to a DataFrame for better visualization
department_percentages = department_counts.unstack()

print(department_percentages)
# Out:
#  Remote Worker      False      True
#  Department
# Finance         52.439024  47.560976
# HR              48.333333  51.666667
# IT              49.438202  50.561798
# Marketing       51.351351  48.648649
# Operations      44.736842  55.263158

# %% [markdown]
# 3.  What is the distribution of Gender across the employees? Is the gender distribution
#  balanced or skewed?
#
# Ans :

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Gender ',data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(True)
plt.show()


#group by department and gender to calulate counts
gender_counts = df.groupby([' Department','Gender ']).size()

#converting to a DataFrame fot better visualization
gender_counts = gender_counts.unstack()
print(gender_counts)
# Out:
# Gender       Female  Male
#  Department
# Finance          49    34
# HR               33    30
# IT               46    51
# Marketing        47    35
# Operations       45    36

# %% [markdown]
# Ans : In Finance Department, female workers are largely engaged.In HR Department, variation of male and female employees is very less.
#
# -In IT Department, most of the engaged employees are male.
#
# -And In both Marketing and Operations Department, female are seemed to be more engaged as per the data.

# %% [markdown]
# Ans : Checking if the gender distribution is balanced or skewed.

# %%
#calculating gender distributions
gender_counts = df['Gender '].value_counts()
print("Gender Distribution:")
print(gender_counts)


#checking balanced or skewed
total = gender_counts.sum()
for gender, count in gender_counts.items():
    percentage = (count / total) * 100
    print(f"{gender}: {percentage:.2f}%")
# Out:
# Gender Distribution:
# Gender
# Female    220
# Male      186
# Name: count, dtype: int64
# Female: 54.19%
# Male: 45.81%

# %% [markdown]
# Ans : As per the data, the gender distibution can be considered as balanced as there is less difference between them.

# %% [markdown]
# ### 6. Performance and Salary Analysis :
#
# 1. Is there any significant difference in the average Salary for different Departments?
#  Which department has the highest average salary?
#
# Ans :

# %%
#calculating average salary for each department
avg_salary_by_dept = df.groupby(' Department')['Salary'].mean()
print(f"Average salary by department : {avg_salary_by_dept}")

print("\n")

#calculating difference for each department's salary
salary_range = df['Salary'].max() - df['Salary'].min()
print(f"\nRange of salaries: {salary_range:.2f}")

#calculating the department with highest avg salary 
highest_salary_department = df.loc[df['Salary'].idxmax()]
print(f"The department with the highest average salary is {highest_salary_department[' Department']} with an average salary of {highest_salary_department['Salary']:.2f}.")
# Out:
# Average salary by department :  Department
# Finance       6001.955708
# HR            6048.505390
# IT            5819.066523
# Marketing     5955.482703
# Operations    5915.610527
# Name: Salary, dtype: float64
#
#
#
# Range of salaries: 3927.00
# The department with the highest average salary is Operations with an average salary of 7957.00.

# %% [markdown]
# Ans : Hence,the significant difference in the average salary for different Departments is 3927.00. And,the department that has higher salary is Operation Department as per the data.

# %% [markdown]
# 2. Isthere a significant difference in Salary based on Gender (e.g., do males and
#  females have a similar salary distribution)
#
# Ans:

# %%
#calculating average salaryby gender

# Calculate the average salary for each gender
male_avg_salary = df[df['Gender '] == 'Male']['Salary'].mean()
female_avg_salary = df[df['Gender '] == 'Female']['Salary'].mean()

# Output the results
print(f"Average salary for males: {male_avg_salary:.2f}")
print(f"Average salary for females: {female_avg_salary:.2f}")

#calculating difference
diff_salary = (male_avg_salary) - (female_avg_salary)
print(f"The difference in Salary by gender : {diff_salary}")
# Out:
# Average salary for males: 6018.76
# Average salary for females: 5871.32
# The difference in Salary by gender : 147.43937755407842

# %% [markdown]
# Ans : As per the data we can clearly see the difference between the salary by gender is only 200 by average. So,here is no significant difference in salary based on gender.

# %% [markdown]
# 3.  What isthe relationship between Performance Rating and Salary? Does
#  performance correlate with pay?
#
# Ans :

# %%
# calculating the correlation coefficient between performance rating and salary
correlation = np.corrcoef(df['Performance Rating'], df['Salary'])[0, 1]

#result of correlation
print(f"The correlation coefficient between Performance Rating and Salary is: {correlation:.2f}")

# Interpretation of the correlation
if correlation > 0.5:
    print("There is a strong positive correlation between Performance Rating and Salary.")
elif correlation > 0:
    print("There is a moderate positive correlation between Performance Rating and Salary.")
elif correlation == 0:
    print("There is no linear correlation between Performance Rating and Salary.")
elif correlation < -0.5:
    print("There is a strong negative correlation between Performance Rating and Salary.")
else:
    print("There is a moderate negative correlation between Performance Rating and Salary.")
# Out:
# The correlation coefficient between Performance Rating and Salary is: 0.01
# There is a moderate positive correlation between Performance Rating and Salary.

# %% [markdown]
# Ans : Hence, as per the data There is a strong positive correlation between Performance Rating and Salary.
